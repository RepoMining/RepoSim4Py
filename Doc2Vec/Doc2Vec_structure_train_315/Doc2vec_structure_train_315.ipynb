# %% [markdown]
# # Doc2Vec to structure (315 repositories / train set)

# %% [markdown]
# ## 1. Downloading the train set

# %%
# !pip3 install gdown
# !gdown 13Z-ReDj4QcwlfvIgUlL6MNE5W2dcPmLr
# Out:
# Requirement already satisfied: gdown in /opt/homebrew/lib/python3.11/site-packages (4.7.1)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from gdown) (3.12.2)
# Requirement already satisfied: requests[socks] in /opt/homebrew/lib/python3.11/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /opt/homebrew/lib/python3.11/site-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (from gdown) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/lib/python3.11/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/lib/python3.11/site-packages (from beautifulsoup4->gdown) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests[socks]->gdown) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests[socks]->gdown) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests[socks]->gdown) (2023.5.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/homebrew/lib/python3.11/site-packages (from requests[socks]->gdown) (1.7.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=13Z-ReDj4QcwlfvIgUlL6MNE5W2dcPmLr
# From (redirected): https://drive.google.com/uc?id=13Z-ReDj4QcwlfvIgUlL6MNE5W2dcPmLr&confirm=t&uuid=36866826-e35e-4b69-b8bf-8a1ac1fbf562
# To: /Users/Henry/Documents/PyCharmProjects/RepoSim4Py/Doc2vec/Doc2vec_readme_train_315/repo_info_train.pkl
# 100%|████████████████████████████████████████| 202M/202M [00:10<00:00, 19.0MB/s]

# %%
import pickle

with open("repo_info_train.pkl", "rb") as f:
    repo_info_train = pickle.load(f)
    f.close()

# %%
next(iter(repo_info_train.keys()))
# Out:
# 'jet-admin/jet-bridge'

# %%
type(repo_info_train[next(iter(repo_info_train.keys()))]["structure"]) # list
# Out:
# list

# %%
repo_info_train[next(iter(repo_info_train.keys()))]["structure"]
# Out:
# [{'release-tasks.sh': 'sh file',
#   'install_jet.sh': 'sh file',
#   '.deepsource.toml': 'toml file',
#   'Dockerfile': 'docker file',
#   'README.md': 'text file',
#   'promotion.png': 'plot file',
#   'LICENSE': 'license file',
#   'app.json': 'json file',
#   'requirements.txt': 'requirements file',
#   'runtime.txt': 'text file',
#   '.gitignore': 'git file',
#   'Procfile': 'procfile file',
#   'scripts': {'set_tags.sh': 'sh file', 'upload_all.sh': 'sh file'},
#   'static': {'customize.jpg': 'jpg file',
#    'overview.gif': 'gif file',
#    'dashboard.png': 'plot file',
#    'filters.png': 'plot file',
#    'segment.png': 'plot file',
#    'kanban.jpeg': 'jpeg file',
#    'list.jpeg': 'jpeg file',
#    'dashboard.jpeg': 'jpeg file',
#    'promotion2.png': 'plot file',
#    'users.png': 'plot file',
#    'promotion.png': 'plot file',
#    'kanban.png': 'plot file',
#    'filters.jpeg': 'jpeg file',
#    'customize.png': 'plot file',
#    'segment.jpeg': 'jpeg file',
#    'users.jpeg': 'jpeg file',
#    'export.jpeg': 'jpeg file',
#    'list.png': 'plot file'},
#   'docker': {'entrypoint.sh': 'sh file', 'network-entrypoint.sh': 'sh file'},
#   'packages': {'__init__.py': 'python script',
#    'jet_bridge': {'upload.sh': 'sh file',
#     'MANIFEST.in': 'in file',
#     'README.md': 'text file',
#     'LICENSE': 'license file',
#     'setup.py': 'setup file',
#     'jet_bridge': {'__init__.py': 'python script',
#      'router.py': 'python script',
#      '__main__.py': 'python script',
#      'configuration.py': 'python script',
#      'settings.py': 'python script',
#      'app.py': 'python script',
#      'media.py': 'python script',
#      'handlers': {'not_found.py': 'python script',
#       '__init__.py': 'python script',
#       'view.py': 'python script',
#       'temporary_redirect.py': 'python script'},
#      'utils': {'__init__.py': 'python script',
#       'create_config.py': 'python script',
#       'settings.py': 'python script'},
#      'commands': {'__init__.py': 'python script'}}},
#    'jet_django': {'upload.sh': 'sh file',
#     'MANIFEST.in': 'in file',
#     'README.rst': 'rst file',
#     'LICENSE': 'license file',
#     'setup.py': 'setup file',
#     'manage.py': 'python script',
#     'jet_django': {'__init__.py': 'python script',
#      'router.py': 'python script',
#      'route_view.py': 'python script',
#      'configuration.py': 'python script',
#      'apps.py': 'python script',
#      'settings.py': 'python script',
#      'urls.py': 'python script',
#      'migrations': {'0002_auto_20181014_2002.py': 'python script',
#       '0003_auto_20191007_2005.py': 'python script',
#       '__init__.py': 'python script',
#       '0001_initial.py': 'python script'}}},
#    'jet_bridge_base': {'upload.sh': 'sh file',
#     'MANIFEST.in': 'in file',
#     'README.md': 'text file',
#     'LICENSE': 'license file',
#     'setup.py': 'setup file',
#     'jet_bridge_base': {'reflect.py': 'python script',
#      'media_cache.py': 'python script',
#      '__init__.py': 'python script',
#      'store.py': 'python script',
#      'ssh_tunnel.py': 'python script',
#      'sentry.py': 'python script',
#      'router.py': 'python script',
#      'request.py': 'python script',
#      'db.py': 'python script',
#      'permissions.py': 'python script',
#      'messages.py': 'python script',
#      'logger.py': 'python script',
#      'configuration.py': 'python script',
#      'encoders.py': 'python script',
#      'settings.py': 'python script',
#      'status.py': 'python script',
#      'fields': {'boolean.py': 'python script',
#       '__init__.py': 'python script',
#       'sql_params.py': 'python script',
#       'integer.py': 'python script',
#       'array.py': 'python script',
#       'raw.py': 'python script',
#       'field.py': 'python script',
#       'float.py': 'python script',
#       'json.py': 'python script',
#       'char.py': 'python script',
#       'datetime.py': 'python script',
#       'wkt.py': 'python script'},
#      'exceptions': {'not_found.py': 'python script',
#       '__init__.py': 'python script',
#       'validation_error.py': 'python script',
#       'api.py': 'python script',
#       'missing_argument_error.py': 'python script',
#       'permission_denied.py': 'python script',
#       'sql.py': 'python script',
#       'request_error.py': 'python script'},
#      'views': {'table_column.py': 'python script',
#       '__init__.py': 'python script',
#       'api.py': 'python script',
#       'image_resize.py': 'python script',
#       'trigger_exception.py': 'python script',
#       'register.py': 'python script',
#       'graphql.py': 'python script',
#       'model.py': 'python script',
#       'model_description.py': 'python script',
#       'message.py': 'python script',
#       'model_description_relationship_override.py': 'python script',
#       'file_upload.py': 'python script',
#       'reload.py': 'python script',
#       'proxy_request.py': 'python script',
#       'table.py': 'python script',
#       'discover_table.py': 'python script',
#       'discover_connection.py': 'python script',
#       'sql.py': 'python script',
#       'status.py': 'python script',
#       'mixins': {'list.py': 'python script',
#        'destroy.py': 'python script',
#        '__init__.py': 'python script',
#        'retrieve.py': 'python script',
#        'create.py': 'python script',
#        'model.py': 'python script',
#        'update.py': 'python script'},
#       'base': {'generic_api.py': 'python script',
#        '__init__.py': 'python script',
#        'api.py': 'python script'},
#       'external_auth': {'login.py': 'python script',
#        '__init__.py': 'python script',
#        'complete.py': 'python script'}},
#      'paginators': {'pagination.py': 'python script',
#       '__init__.py': 'python script',
#       'page_number.py': 'python script'},
#      'filters': {'model_aggregate.py': 'python script',
#       'model_relation.py': 'python script',
#       'integer_filter.py': 'python script',
#       'lookups.py': 'python script',
#       '__init__.py': 'python script',
#       'char_filter.py': 'python script',
#       'model_segment.py': 'python script',
#       'wkt_filter.py': 'python script',
#       'filter_class.py': 'python script',
#       'model.py': 'python script',
#       'model_search.py': 'python script',
#       'filter_for_dbfield.py': 'python script',
#       'model_group.py': 'python script',
#       'filter.py': 'python script',
#       'boolean_filter.py': 'python script',
#       'float_filter.py': 'python script',
#       'datetime_filter.py': 'python script',
#       'order_by.py': 'python script',
#       'model_m2m.py': 'python script'},
#      'external_auth': {'pipeline.py': 'python script',
#       '__init__.py': 'python script',
#       'utils.py': 'python script',
#       'mixin.py': 'python script',
#       'strategy.py': 'python script',
#       'storage.py': 'python script'},
#      'models': {'__init__.py': 'python script',
#       'column.py': 'python script',
#       'base.py': 'python script',
#       'data_types.py': 'python script',
#       'table.py': 'python script',
#       'model_relation_override.py': 'python script'},
#      'serializers': {'__init__.py': 'python script',
#       'relationship_override.py': 'python script',
#       'model.py': 'python script',
#       'model_description.py': 'python script',
#       'reset_order.py': 'python script',
#       'message.py': 'python script',
#       'model_group.py': 'python script',
#       'reorder.py': 'python script',
#       'serializer.py': 'python script',
#       'proxy_request.py': 'python script',
#       'table.py': 'python script',
#       'model_serializer.py': 'python script',
#       'sql.py': 'python script'},
#      'templates': {'external_auth_complete.html': 'html file',
#       '500.html': 'html file',
#       '404.html': 'html file',
#       '500.debug.html': 'html file',
#       '403.html': 'html file'},
#      'utils': {'backend.py': 'python script',
#       '__init__.py': 'python script',
#       'track_database.py': 'python script',
#       'type_codes.py': 'python script',
#       'classes.py': 'python script',
#       'async_exec.py': 'python script',
#       'graphql.py': 'python script',
#       'relations.py': 'python script',
#       'exceptions.py': 'python script',
#       'gql.py': 'python script',
#       'http.py': 'python script',
#       'common.py': 'python script',
#       'queryset.py': 'python script',
#       'crypt.py': 'python script',
#       'siblings.py': 'python script',
#       'db_types.py': 'python script',
#       'utc.py': 'python script',
#       'track_model.py': 'python script'},
#      'responses': {'template.py': 'python script',
#       'not_found.py': 'python script',
#       '__init__.py': 'python script',
#       'optional_json.py': 'python script',
#       'base.py': 'python script',
#       'redirect.py': 'python script',
#       'json.py': 'python script'},
#      'commands': {'__init__.py': 'python script',
#       'check_token.py': 'python script'}}}},
#   'hooks': {'post_push': 'post_push file'}}]

# %%
" ".join(str(repo_info_train[next(iter(repo_info_train.keys()))]["structure"]))
# Out:
# "[ { ' r e l e a s e - t a s k s . s h ' :   ' s h   f i l e ' ,   ' i n s t a l l _ j e t . s h ' :   ' s h   f i l e ' ,   ' . d e e p s o u r c e . t o m l ' :   ' t o m l   f i l e ' ,   ' D o c k e r f i l e ' :   ' d o c k e r   f i l e ' ,   ' R E A D M E . m d ' :   ' t e x t   f i l e ' ,   ' p r o m o t i o n . p n g ' :   ' p l o t   f i l e ' ,   ' L I C E N S E ' :   ' l i c e n s e   f i l e ' ,   ' a p p . j s o n ' :   ' j s o n   f i l e ' ,   ' r e q u i r e m e n t s . t x t ' :   ' r e q u i r e m e n t s   f i l e ' ,   ' r u n t i m e . t x t ' :   ' t e x t   f i l e ' ,   ' . g i t i g n o r e ' :   ' g i t   f i l e ' ,   ' P r o c f i l e ' :   ' p r o c f i l e   f i l e ' ,   ' s c r i p t s ' :   { ' s e t _ t a g s . s h ' :   ' s h   f i l e ' ,   ' u p l o a d _ a l l . s h ' :   ' s h   f i l e ' } ,   ' s t a t i c ' :   { ' c u s t o m i z e . j p g ' :   ' j p g   f i l e ' ,   ' o v e r v i e w . g i f ' :   ' g i f   f i l e ' ,   ' d a s h b o a r d . p n g ' :   ' p l o t   f i l e ' ,   ' f i l t e r s . p n g ' :   ' p l o t   f i l e ' ,   ' s e g m e n t . p n g ' :   ' p l o t   f i l e ' ,   ' k a n b a n . j p e g ' :   ' j p e g   f i l e ' ,   ' l i s t . j p e g ' :   ' j p e g   f i l e ' ,   ' d a s h b o a r d . j p e g ' :   ' j p e g   f i l e ' ,   ' p r o m o t i o n 2 . p n g ' :   ' p l o t   f i l e ' ,   ' u s e r s . p n g ' :   ' p l o t   f i l e ' ,   ' p r o m o t i o n . p n g ' :   ' p l o t   f i l e ' ,   ' k a n b a n . p n g ' :   ' p l o t   f i l e ' ,   ' f i l t e r s . j p e g ' :   ' j p e g   f i l e ' ,   ' c u s t o m i z e . p n g ' :   ' p l o t   f i l e ' ,   ' s e g m e n t . j p e g ' :   ' j p e g   f i l e ' ,   ' u s e r s . j p e g ' :   ' j p e g   f i l e ' ,   ' e x p o r t . j p e g ' :   ' j p e g   f i l e ' ,   ' l i s t . p n g ' :   ' p l o t   f i l e ' } ,   ' d o c k e r ' :   { ' e n t r y p o i n t . s h ' :   ' s h   f i l e ' ,   ' n e t w o r k - e n t r y p o i n t . s h ' :   ' s h   f i l e ' } ,   ' p a c k a g e s ' :   { ' _ _ i n i t _ _ . p y ' :   ' p y t h o n   s c r i p t ' ,   ' j e t _ b r i d g e ' :   { ' u p l o a d . s h ' :   ' s h   f i l e ' ,   ' M A N I F E S T . i n ' :   ' i n   f i l e ' ,   ' R E A D M E . m d ' :   ' t e x t   f i l e ' ,   ' L I C E N S E ' :   ' l i c e n s e   f i l e ' ,   ' s e t u p . p y ' :   ' s e t u p   f i l e ' ,   ' j e t _ b r i d g e ' :   { ' _ _ i n i t _ _ . p y ' :   ' p y t h o n   s c r i p t ' ,   ' r o u t e r . p y ' :   ' p y t h o n   s c r i p t ' ,   ' _ _ m a i n _ _ . p y ' :   ' p y t h o n   s c r i p t ' ,   ' c o n f i g u r a t i o n . p y ' :   ' p y t h o n   s c r i p t ' ,   ' s e t t i n g s . p y ' :   ' p y t h o n   s c r i p t ' ,   ' a p p . p y ' :   ' p y t h o n   s c r i p t ' ,   ' m e d i a . p y ' :   ' p y t h o n   s c r i p t ' ,   ' h a n d l e r s ' :   { ' n o t _ f o u n d . p y ' :   ' p y t h o n   s c r i p t ' ,   ' _ _ i n i t _ _ . p y ' :   ' p y t h o n   s c r i p t ' ,   ' v i e w . p y ' :   ' p y t h o n   s c r i p t ' ,   ' t e m p o r a r y _ r e d i r e c t . p y ' :   ' p y t h o n   s c r i p t ' } ,   ' u t i l s ' :   { ' _ _ i n i t _ _ . p y ' :   ' p y t h o n   s c r i p t ' ,   ' c r e a t e _ c o n f i g . p y ' :   ' p y t h o n   s c r i p t ' ,   ' s e t t i n g s . p y ' :   ' p y t h o n   s c r i p t ' } ,   ' c o m m a n d s ' :   { ' _ _ i n i t _ _ . p y ' :   ' p y t h o n   s c r i p t ' } } } ,   ' j e t _ d j a n g o ' :   { ' u p l o a d . s h ' :   ' s h   f i l e ' ,   ' M A N I F E S T . i n ' :   ' i n   f i l e ' ,   ' R E A D M E . r s t ' :   ' r s t   f i l e ' ,   ' L I C E N S E ' :   ' l i c e n s e   f i l e ' ,   ' s e t u p . p y ' :   ' s e t u p   f i l e ' ,   ' m a n a g e . p y ' :   ' p y t h o n   s c r i p t ' ,   ' j e t _ d j a n g o ' :   { ' _ _ i n i t _ _ . p y ' :   ' p y t h o n   s c r i p t ' ,   ' r o u t e r . p y ' :   ' p y t h o n   s c r i p ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
labels = [repo_info_train[repo_name]["topic"] for repo_name in list(repo_info_train.keys())]
encoded_labels = label_encoder.fit_transform(labels)

# Print the encoded labels
print(encoded_labels)
# Out:
# [  1  64  32  25  52  18  41  95  72  10  24 103  60 106  15  50  13  75
#   29  44  82 112  36  39  49  83  58  58 118  43  63  66   2  93 109  48
#   29  70  78   4  67  43  28  87 117 104  91  64  72  52  55  29  91   2
#   90  64  83  41  72 109  74  56  96  16 109  17  29 117 112  67  77  14
#   54  10   9  72  82  97  76  46  31  43  99  21 118  98   7  96  62  74
#   79  57 105  83  30  49   7  75  60  44  13  59  98  86  52 116  52  29
#   37 111 110  26  15 115  31  49  31  92 113   6  72 116  66  83   3  69
#   21 111  42  22  81  51  69  47  16  22 109  27  51  68 115   2  93 117
#   64  70  91  84  49  76  13 109  91   0  11  47  56  98  31  34   6  37
#   40  40  70  47  58  53 117  68  63   1  44 118  52 101  44  58  43  80
#    9 108  91 118  66  24  71  91  91  97 110  22  87  38  13  45   9  82
#   86  47  47 114  26 116 117  19 113  41 107 115  43  47  94  27  48  56
#   12  33  25  49  37  45  96  25  41  32  56   8  19 104  62 100 104   6
#   76  56  72  97 119   6  11  23  27  52  25  74  46  47   1  26  49  62
#   63  44  47  88 117  30  26  72  45   5  29  50  20  11  10  10   1  89
#   70  85   9  50  24  19  46  33  97  86  19   1  65  92 111  73  86  81
#  100  51  11 102  97  50  61  35  26  69  44  87  59  37 117  97  36  31
#   37  75  53  20  98  56   7  94  63]

# %% [markdown]
# ## 2. Processing data and building corpus

# %%
# !pip3 install gensim
# Out:
# Requirement already satisfied: gensim in /opt/homebrew/lib/python3.11/site-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in /opt/homebrew/lib/python3.11/site-packages (from gensim) (1.25.0)
# Requirement already satisfied: scipy>=1.7.0 in /opt/homebrew/lib/python3.11/site-packages (from gensim) (1.11.1)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/homebrew/lib/python3.11/site-packages (from gensim) (6.3.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
# Building the corpus
corpus = []
for repo_name, repo_dict in repo_info_train.items():
    structure_str = " ".join(str(repo_info_train[repo_name]["structure"]))
    corpus.append(structure_str)

# %%
len(corpus)
# Out:
# 315

# %%
file_path = "structure_train_corpus.txt"

with open(file_path, "w") as file:
    for sentence in corpus:
        file.write(sentence + "\n")

file.close()

# %% [markdown]
# ## 3. Building doc2vec model

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import gensim
import smart_open

# Read corpus: an iterator
def read_corpus(fname, tokens_only=False):
    with smart_open.open(fname, encoding="utf-8") as f:
        for i, line in enumerate(f):
            tokens = gensim.utils.simple_preprocess(line)
            if tokens_only:
                yield tokens
            else:
                # For training data, add tags
                yield gensim.models.doc2vec.TaggedDocument(str(tokens), [encoded_labels[i]])

train_corpus = list(read_corpus(file_path))

# %%
len(train_corpus)
# Out:
# 315

# %%
# Building the Doc2Vec model.
model = gensim.models.doc2vec.Doc2Vec(vector_size=10, min_count=2, epochs=100)
# Out:
# 2023-07-06 19:18:12,865 : INFO : Doc2Vec lifecycle event {'params': 'Doc2Vec<dm/m,d10,n5,w5,mc2,s0.001,t3>', 'datetime': '2023-07-06T19:18:12.865570', 'gensim': '4.3.1', 'python': '3.10.12 (main, Jun 20 2023, 19:43:52) [Clang 14.0.3 (clang-1403.0.22.14.1)]', 'platform': 'macOS-13.4.1-arm64-arm-64bit', 'event': 'created'}

# %%
# Adding corpus to model.
model.build_vocab(train_corpus)
# Out:
# 2023-07-06 19:18:14,236 : INFO : collecting all words and their counts
# 2023-07-06 19:18:14,237 : WARNING : Each 'words' should be a list of words (usually unicode strings). First 'words' here is instead plain <class 'str'>.
# 2023-07-06 19:18:14,238 : INFO : PROGRESS: at example #0, processed 0 words (0 words/s), 0 word types, 0 tags
# 2023-07-06 19:18:14,240 : INFO : collected 2 word types and 120 unique tags from a corpus of 315 examples and 630 words
# 2023-07-06 19:18:14,241 : INFO : Creating a fresh vocabulary
# 2023-07-06 19:18:14,242 : INFO : Doc2Vec lifecycle event {'msg': 'effective_min_count=2 retains 2 unique words (100.00% of original 2, drops 0)', 'datetime': '2023-07-06T19:18:14.242113', 'gensim': '4.3.1', 'python': '3.10.12 (main, Jun 20 2023, 19:43:52) [Clang 14.0.3 (clang-1403.0.22.14.1)]', 'platform': 'macOS-13.4.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2023-07-06 19:18:14,242 : INFO : Doc2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 630 word corpus (100.00% of original 630, drops 0)', 'datetime': '2023-07-06T19:18:14.242840', 'gensim': '4.3.1', 'python': '3.10.12 (main, Jun 20 2023, 19:43:52) [Clang 14.0.3 (clang-1403.0.22.14.1)]', 'platform': 'macOS-13.4.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2023-07-06 19:18:14,243 : INFO : deleting the raw counts dictionary of 2 items
# 2023-07-06 19:18:14,244 : INFO : sample=0.001 downsamples 2 most-common words
# 2023-07-06 19:18:14,245 : INFO : Doc2Vec lifecycle event {'msg': 'downsampling leaves estimated 29.434456516497352 word corpus (4.7%% of prior 630)', 'datetime': '2023-07-06T19:18:14.245233', 'gensim': '4.3.1', 'python': '3.10.12 (main, Jun 20 2023, 19:43:52) [Clang 14.0.3 (clang-1403.0.22.14.1)]', 'platform': 'macOS-13.4.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2023-07-06 19:18:14,246 : INFO : estimated required memory for 2 words and 10 dimensions: 29960 bytes
# 2023-07-06 19:18:14,246 : INFO : resetting layer weights

# %%
# Training
model.train(train_corpus, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# 2023-07-06 19:18:17,854 : INFO : Doc2Vec lifecycle event {'msg': 'training model with 3 workers on 2 vocabulary and 10 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2023-07-06T19:18:17.854491', 'gensim': '4.3.1', 'python': '3.10.12 (main, Jun 20 2023, 19:43:52) [Clang 14.0.3 (clang-1403.0.22.14.1)]', 'platform': 'macOS-13.4.1-arm64-arm-64bit', 'event': 'train'}
# 2023-07-06 19:18:17,870 : INFO : EPOCH 0: training on 630 raw words (335 effective words) took 0.0s, 32143 effective words/s
# 2023-07-06 19:18:17,880 : INFO : EPOCH 1: training on 630 raw words (344 effective words) took 0.0s, 163020 effective words/s
# 2023-07-06 19:18:17,887 : INFO : EPOCH 2: training on 630 raw words (348 effective words) took 0.0s, 15878832 effective words/s
# 2023-07-06 19:18:17,895 : INFO : EPOCH 3: training on 630 raw words (341 effective words) took 0.0s, 447899 effective words/s
# 2023-07-06 19:18:17,903 : INFO : EPOCH 4: training on 630 raw words (350 effective words) took 0.0s, 16700076 effective words/s
# 2023-07-06 19:18:17,910 : INFO : EPOCH 5: training on 630 raw words (352 effective words) took 0.0s, 14952018 effective words/s
# 2023-07-06 19:18:17,916 : INFO : EPOCH 6: training on 630 raw words (350 effective words) took 0.0s, 16184979 effective words/s
# 2023-07-06 19:18:17,922 : INFO : EPOCH 7: training on 630 raw words (343 effective words) took 0.0s, 109247 effective words/s
# 2023-07-06 19:18:17,927 : INFO : EPOCH 8: training on 630 raw words (338 effective words) took 0.0s, 86163 effective words/s
# 2023-07-06 19:18:17,932 : INFO : EPOCH 9: training on 630 raw words (341 effective words) took 0.0s, 18987711 effective words/s
# 2023-07-06 19:18:17,936 : INFO : EPOCH 10: training on 630 raw words (348 effective words) took 0.0s, 139684 effective words/s
# 2023-07-06 19:18:17,941 : INFO : EPOCH 11: training on 630 raw words (344 effective words) took 0.0s, 123884 effective words/s
# 2023-07-06 19:18:17,945 : INFO : EPOCH 12: training on 630 raw words (347 effective words) took 0.0s, 194498 effective words/s
# 2023-07-06 19:18:17,950 : INFO : EPOCH 13: training on 630 raw words (339 effective words) took 0.0s, 323280 effective words/s
# 2023-07-06 19:18:17,960 : INFO : EPOCH 14: training on 630 raw words (351 effective words) took 0.0s, 98958 effective words/s
# 2023-07-06 19:18:17,966 : INFO : EPOCH 15: training on 630 raw words (350 effective words) took 0.0s, 93086 effective words/s
# 2023-07-06 19:18:17,970 : INFO : EPOCH 16: training on 630 raw words (347 effective words) took 0.0s, 21464823 effective words/s
# 2023-07-06 19:18:17,974 : INFO : EPOCH 17: training on 630 raw words (343 effective words) took 0.0s, 112914 effective words/s
# 2023-07-06 19:18:17,978 : INFO : EPOCH 18: training on 630 raw words (344 effective words) took 0.0s, 159475 effective words/s
# 2023-07-06 19:18:17,982 : INFO : EPOCH 19: training on 630 raw words (353 effective words) took 0.0s, 138158 effective words/s
# 2023-07-06 19:18:17,985 : INFO : EPOCH 20: training on 630 raw words (341 effective words) took 0.0s, 163415 effective words/s
# 2023-07-06 19:18:17,989 : INFO : EPOCH 21: training on 630 raw words (357 effective words) took 0.0s, 23219511 effective words/s
# 2023-07-06 19:18:17,993 : INFO : EPOCH 22: training on 630 raw words (343 effective words) took 0.0s, 152943 effective words/s
# 2023-07-06 19:18:17,997 : INFO : EPOCH 23: training on 630 raw words (342 effective words) took 0.0s, 203193 effective words/s
# 2023-07-06 19:18:18,000 : INFO : EPOCH 24: training on 630 raw words (342 effective words) took 0.0s, 770560 effective words/s
# 2023-07-06 19:18:18,005 : INFO : EPOCH 25: training on 630 raw words (350 effective words) took 0.0s, 678459 effective words/s
# 2023-07-06 19:18:18,009 : INFO : EPOCH 26: training on 630 raw words (348 effective words) took 0.0s, 344313 effective words/s
# 2023-07-06 19:18:18,012 : INFO : EPOCH 27: training on 630 raw words (347 effective words) took 0.0s, 192822 effective words/s
# 2023-07-06 19:18:18,016 : INFO : EPOCH 28: training on 630 raw words (346 effective words) took 0.0s, 136073 effective words/s
# 2023-07-06 19:18:18,020 : INFO : EPOCH 29: training on 630 raw words (353 effective words) took 0.0s, 112117 effective words/s
# 2023-07-06 19:18:18,024 : INFO : EPOCH 30: training on 630 raw words (338 effective words) took 0.0s, 115930 effective words/s
# 2023-07-06 19:18:18,027 : INFO : EPOCH 31: training on 630 raw words (346 effective words) took 0.0s, 155058 effective words/s
# 2023-07-06 19:18:18,031 : INFO : EPOCH 32: training on 630 raw words (346 effective words) took 0.0s, 129028 effective words/s
# 2023-07-06 19:18:18,034 : INFO : EPOCH 33: training on 630 raw words (342 effective words) took 0.0s, 159360 effective words/s
# 2023-07-06 19:18:18,039 : INFO : EPOCH 34: training on 630 raw words (345 effective words) took 0.0s, 1864452 effective words/s
# 2023-07-06 19:18:18,043 : INFO : EPOCH 35: training on 630 raw words (340 effective words) took 0.0s, 146161 effective words/s
# 2023-07-06 19:18:18,047 : INFO : EPOCH 36: training on 630 raw words (338 effective words) took 0.0s, 117351 effective words/s
# 2023-07-06 19:18:18,051 : INFO : EPOCH 37: training on 630 raw words (342 effective words) took 0.0s, 151868 effective words/s
# 2023-07-06 19:18:18,055 : INFO : EPOCH 38: training on 630 raw words (342 effective words) took 0.0s, 106221 effective words/s
# 2023-07-06 19:18:18,058 : INFO : EPOCH 39: training on 630 raw words (351 effective words) took 0.0s, 151217 effective words/s
# 2023-07-06 19:18:18,062 : INFO : EPOCH 40: training on 630 raw words (340 effective words) took 0.0s, 132000 effective words/s
# 2023-07-06 19:18:18,065 : INFO : EPOCH 41: training on 630 raw words (341 effective words) took 0.0s, 144750 effective words/s
# 2023-07-06 19:18:18,069 : INFO : EPOCH 42: training on 630 raw words (355 effective words) took 0.0s, 174255 effective words/s
# 2023-07-06 19:18:18,073 : INFO : EPOCH 43: training on 630 raw words (339 effective words) took 0.0s, 99461 effective words/s
# 2023-07-06 19:18:18,077 : INFO : EPOCH 44: training on 630 raw words (342 effective words) took 0.0s, 136058 effective words/s
# 2023-07-06 19:18:18,081 : INFO : EPOCH 45: training on 630 raw words (338 effective words) took 0.0s, 189710 effective words/s
# 2023-07-06 19:18:18,084 : INFO : EPOCH 46: training on 630 raw words (349 effective words) took 0.0s, 366132 effective words/s
# 2023-07-06 19:18:18,088 : INFO : EPOCH 47: training on 630 raw words (338 effective words) took 0.0s, 112050 effective words/s
# 2023-07-06 19:18:18,092 : INFO : EPOCH 48: training on 630 raw words (335 effective words) took 0.0s, 361950 effective words/s
# 2023-07-06 19:18:18,096 : INFO : EPOCH 49: training on 630 raw words (340 effective words) took 0.0s, 21031815 effective words/s
# 2023-07-06 19:18:18,099 : INFO : EPOCH 50: training on 630 raw words (346 effective words) took 0.0s, 157452 effective words/s
# 2023-07-06 19:18:18,103 : INFO : EPOCH 51: training on 630 raw words (338 effective words) took 0.0s, 125734 effective words/s
# 2023-07-06 19:18:18,106 : INFO : EPOCH 52: training on 630 raw words (347 effective words) took 0.0s, 117955 effective words/s
# 2023-07-06 19:18:18,110 : INFO : EPOCH 53: training on 630 raw words (337 effective words) took 0.0s, 480285 effective words/s
# 2023-07-06 19:18:18,114 : INFO : EPOCH 54: training on 630 raw words (339 effective words) took 0.0s, 144396 effective words/s
# 2023-07-06 19:18:18,118 : INFO : EPOCH 55: training on 630 raw words (347 effective words) took 0.0s, 215489 effective words/s
# 2023-07-06 19:18:18,122 : INFO : EPOCH 56: training on 630 raw words (335 effective words) took 0.0s, 167041 effective words/s
# 2023-07-06 19:18:18,125 : INFO : EPOCH 57: training on 630 raw words (348 effective words) took 0.0s, 148430 effective words/s
# 2023-07-06 19:18:18,129 : INFO : EPOCH 58: training on 630 raw words (332 effective words) took 0.0s, 132570 effective words/s
# 2023-07-06 19:18:18,132 : INFO : EPOCH 59: training on 630 raw words (337 effective words) took 0.0s, 121895 effective words/s
# 2023-07-06 19:18:18,136 : INFO : EPOCH 60: training on 630 raw words (342 effective words) took 0.0s, 152460 effective words/s
# 2023-07-06 19:18:18,140 : INFO : EPOCH 61: training on 630 raw words (346 effective words) took 0.0s, 151092 effective words/s
# 2023-07-06 19:18:18,143 : INFO : EPOCH 62: training on 630 raw words (347 effective words) took 0.0s, 215188 effective words/s
# 2023-07-06 19:18:18,147 : INFO : EPOCH 63: training on 630 raw words (347 effective words) took 0.0s, 427647 effective words/s
# 2023-07-06 19:18:18,151 : INFO : EPOCH 64: training on 630 raw words (341 effective words) took 0.0s, 176821 effective words/s
# 2023-07-06 19:18:18,155 : INFO : EPOCH 65: training on 630 raw words (346 effective words) took 0.0s, 274159 effective words/s
# 2023-07-06 19:18:18,158 : INFO : EPOCH 66: training on 630 raw words (346 effective words) took 0.0s, 22688525 effective words/s
# 2023-07-06 19:18:18,162 : INFO : EPOCH 67: training on 630 raw words (345 effective words) took 0.0s, 159439 effective words/s
# 2023-07-06 19:18:18,165 : INFO : EPOCH 68: training on 630 raw words (351 effective words) took 0.0s, 124857 effective words/s
# 2023-07-06 19:18:18,169 : INFO : EPOCH 69: training on 630 raw words (344 effective words) took 0.0s, 160105 effective words/s
# 2023-07-06 19:18:18,173 : INFO : EPOCH 70: training on 630 raw words (344 effective words) took 0.0s, 126634 effective words/s
# 2023-07-06 19:18:18,177 : INFO : EPOCH 71: training on 630 raw words (345 effective words) took 0.0s, 22746759 effective words/s
# 2023-07-06 19:18:18,181 : INFO : EPOCH 72: training on 630 raw words (342 effective words) took 0.0s, 8257480 effective words/s
# 2023-07-06 19:18:18,184 : INFO : EPOCH 73: training on 630 raw words (350 effective words) took 0.0s, 141679 effective words/s
# 2023-07-06 19:18:18,188 : INFO : EPOCH 74: training on 630 raw words (342 effective words) took 0.0s, 134635 effective words/s
# 2023-07-06 19:18:18,192 : INFO : EPOCH 75: training on 630 raw words (344 effective words) took 0.0s, 240665 effective words/s
# 2023-07-06 19:18:18,195 : INFO : EPOCH 76: training on 630 raw words (349 effective words) took 0.0s, 118879 effective words/s
# 2023-07-06 19:18:18,199 : INFO : EPOCH 77: training on 630 raw words (347 effective words) took 0.0s, 127299 effective words/s
# 2023-07-06 19:18:18,202 : INFO : EPOCH 78: training on 630 raw words (339 effective words) took 0.0s, 108697 effective words/s
# 2023-07-06 19:18:18,207 : INFO : EPOCH 79: training on 630 raw words (348 effective words) took 0.0s, 6186668 effective words/s
# 2023-07-06 19:18:18,210 : INFO : EPOCH 80: training on 630 raw words (330 effective words) took 0.0s, 126744 effective words/s
# 2023-07-06 19:18:18,214 : INFO : EPOCH 81: training on 630 raw words (338 effective words) took 0.0s, 170341 effective words/s
# 2023-07-06 19:18:18,217 : INFO : EPOCH 82: training on 630 raw words (348 effective words) took 0.0s, 135334 effective words/s
# 2023-07-06 19:18:18,221 : INFO : EPOCH 83: training on 630 raw words (349 effective words) took 0.0s, 126551 effective words/s
# 2023-07-06 19:18:18,225 : INFO : EPOCH 84: training on 630 raw words (346 effective words) took 0.0s, 8560967 effective words/s
# 2023-07-06 19:18:18,228 : INFO : EPOCH 85: training on 630 raw words (341 effective words) took 0.0s, 1311538 effective words/s
# 2023-07-06 19:18:18,232 : INFO : EPOCH 86: training on 630 raw words (345 effective words) took 0.0s, 212014 effective words/s
# 2023-07-06 19:18:18,236 : INFO : EPOCH 87: training on 630 raw words (351 effective words) took 0.0s, 115926 effective words/s
# 2023-07-06 19:18:18,240 : INFO : EPOCH 88: training on 630 raw words (346 effective words) took 0.0s, 118607 effective words/s
# 2023-07-06 19:18:18,243 : INFO : EPOCH 89: training on 630 raw words (345 effective words) took 0.0s, 125654 effective words/s
# 2023-07-06 19:18:18,247 : INFO : EPOCH 90: training on 630 raw words (344 effective words) took 0.0s, 187270 effective words/s
# 2023-07-06 19:18:18,251 : INFO : EPOCH 91: training on 630 raw words (346 effective words) took 0.0s, 117124 effective words/s
# 2023-07-06 19:18:18,254 : INFO : EPOCH 92: training on 630 raw words (344 effective words) took 0.0s, 108052 effective words/s
# 2023-07-06 19:18:18,258 : INFO : EPOCH 93: training on 630 raw words (339 effective words) took 0.0s, 22852922 effective words/s
# 2023-07-06 19:18:18,261 : INFO : EPOCH 94: training on 630 raw words (343 effective words) took 0.0s, 133040 effective words/s
# 2023-07-06 19:18:18,265 : INFO : EPOCH 95: training on 630 raw words (340 effective words) took 0.0s, 22985409 effective words/s
# 2023-07-06 19:18:18,268 : INFO : EPOCH 96: training on 630 raw words (345 effective words) took 0.0s, 223361 effective words/s
# 2023-07-06 19:18:18,272 : INFO : EPOCH 97: training on 630 raw words (354 effective words) took 0.0s, 165224 effective words/s
# 2023-07-06 19:18:18,276 : INFO : EPOCH 98: training on 630 raw words (342 effective words) took 0.0s, 2024663 effective words/s
# 2023-07-06 19:18:18,279 : INFO : EPOCH 99: training on 630 raw words (339 effective words) took 0.0s, 20545443 effective words/s
# 2023-07-06 19:18:18,280 : INFO : Doc2Vec lifecycle event {'msg': 'training on 63000 raw words (34410 effective words) took 0.4s, 81044 effective words/s', 'datetime': '2023-07-06T19:18:18.280034', 'gensim': '4.3.1', 'python': '3.10.12 (main, Jun 20 2023, 19:43:52) [Clang 14.0.3 (clang-1403.0.22.14.1)]', 'platform': 'macOS-13.4.1-arm64-arm-64bit', 'event': 'train'}

# %%
vector = model.infer_vector(list(str(repo_info_train[next(iter(repo_info_train.keys()))]["structure"])))
vector.shape
# Out:
# (10,)

# %% [markdown]
# ## 4. Similarity calculation

# %%
import torch
from tqdm import tqdm
from torch.nn import CosineSimilarity
from itertools import combinations
import pandas as pd

cossim = CosineSimilarity(dim=0, eps=1e-8)
res = []
num_of_repos = len(repo_info_train)
num_of_rows = num_of_repos * (num_of_repos - 1) // 2

for repo1, repo2 in tqdm(combinations(repo_info_train.keys(), 2), total=num_of_rows):
    row = [repo1, repo2, repo_info_train[repo1]["topic"], repo_info_train[repo2]["topic"]]
    embedding1 = torch.tensor(model.infer_vector(list(str(repo_info_train[repo1]["structure"]))))
    embedding2 = torch.tensor(model.infer_vector(list(str(repo_info_train[repo2]["structure"]))))
    similarity = cossim(embedding1, embedding2).cpu().detach().numpy().item()
    row.append(similarity)

    res.append(row)

df = pd.DataFrame(res, columns=["repo1", "repo2", "topic1", "topic2", "doc2vec_structure"])
df
# Out:
# 100%|███████████████████████████████████| 49455/49455 [3:04:04<00:00,  4.48it/s]
#                          repo1                      repo2  \
# 0         jet-admin/jet-bridge             patrys/httmock
# 1         jet-admin/jet-bridge  pytransitions/transitions
# 2         jet-admin/jet-bridge            keleshev/schema
# 3         jet-admin/jet-bridge           dylanaraps/pywal
# 4         jet-admin/jet-bridge            PyCQA/modernize
# ...                        ...                        ...
# 49450  thauber/django-schedule             Miserlou/Zappa
# 49451  thauber/django-schedule                jek/blinker
# 49452               Yelp/mrjob             Miserlou/Zappa
# 49453               Yelp/mrjob                jek/blinker
# 49454           Miserlou/Zappa                jek/blinker
#
#                       topic1                 topic2  doc2vec_structure
# 0               Admin Panels                   Mock           0.369191
# 1               Admin Panels        Design Patterns           0.700269
# 2               Admin Panels        Data Validation           0.371084
# 3               Admin Panels       Image Processing          -0.138929
# 4               Admin Panels          Compatibility          -0.021582
# ...                      ...                    ...                ...
# 49450          Job Scheduler  Serverless Frameworks          -0.102069
# 49451          Job Scheduler          Miscellaneous           0.401596
# 49452       Batch Processing  Serverless Frameworks          -0.099992
# 49453       Batch Processing          Miscellaneous           0.583447
# 49454  Serverless Frameworks          Miscellaneous           0.177513
#
# [49455 rows x 5 columns]

# %%
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                          repo1                      repo2  \
# 0         jet-admin/jet-bridge             patrys/httmock
# 1         jet-admin/jet-bridge  pytransitions/transitions
# 2         jet-admin/jet-bridge            keleshev/schema
# 3         jet-admin/jet-bridge           dylanaraps/pywal
# 4         jet-admin/jet-bridge            PyCQA/modernize
# ...                        ...                        ...
# 49450  thauber/django-schedule             Miserlou/Zappa
# 49451  thauber/django-schedule                jek/blinker
# 49452               Yelp/mrjob             Miserlou/Zappa
# 49453               Yelp/mrjob                jek/blinker
# 49454           Miserlou/Zappa                jek/blinker
#
#                       topic1                 topic2  doc2vec_structure
# 0               Admin Panels                   Mock           0.369191
# 1               Admin Panels        Design Patterns           0.700269
# 2               Admin Panels        Data Validation           0.371084
# 3               Admin Panels       Image Processing          -0.138929
# 4               Admin Panels          Compatibility          -0.021582
# ...                      ...                    ...                ...
# 49450          Job Scheduler  Serverless Frameworks          -0.102069
# 49451          Job Scheduler          Miscellaneous           0.401596
# 49452       Batch Processing  Serverless Frameworks          -0.099992
# 49453       Batch Processing          Miscellaneous           0.583447
# 49454  Serverless Frameworks          Miscellaneous           0.177513
#
# [49455 rows x 5 columns]

# %%
df.sort_values("doc2vec_structure", ascending=False).reset_index(drop=True)
# Out:
#                          repo1                        repo2  \
# 0      PySimpleGUI/PySimpleGUI          sunainapai/makesite
# 1                 dmlc/xgboost      mozillazg/python-pinyin
# 2         timothycrosley/isort                 nicfit/eyeD3
# 3                   hugapi/hug                nucleic/enaml
# 4          getsentry/responses  AtsushiSakai/PythonRobotics
# ...                        ...                          ...
# 49450            pytoolz/toolz      thauber/django-schedule
# 49451          mahmoud/boltons          pybuilder/pybuilder
# 49452            lektor/lektor             khamidou/lptrace
# 49453          esnme/ultrajson                 dmlc/xgboost
# 49454              geopy/geopy  davidaurelio/hashids-python
#
#                        topic1                                 topic2  \
# 0             GUI Development                  Static Site Generator
# 1            Machine Learning  Specific Formats Processing - General
# 2             Code Formatters                               Metadata
# 3          Framework agnostic                        GUI Development
# 4                        Mock                               Robotics
# ...                       ...                                    ...
# 49450  Functional Programming                          Job Scheduler
# 49451           Miscellaneous                            Build Tools
# 49452   Static Site Generator                                Tracing
# 49453           Serialization                       Machine Learning
# 49454             Geolocation                     Unique identifiers
#
#        doc2vec_structure
# 0               0.937233
# 1               0.934702
# 2               0.929267
# 3               0.923697
# 4               0.919612
# ...                  ...
# 49450          -0.863035
# 49451          -0.870492
# 49452          -0.870839
# 49453          -0.872093
# 49454          -0.899608
#
# [49455 rows x 5 columns]

# %%
df.to_csv("structure_doc2vec_evaluation_train_315.csv")

# %% [markdown]
# ## 5. Evaluation

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

model_auc = {}
y_true = df['topic1'] == df['topic2']
fig = plt.figure(figsize=(12, 10))

model_names = ["doc2vec_structure"]

def roc(model_name):
    y_score = df[model_name]
    fpr, tpr, thresholds = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)
    model_auc[model_name] = roc_auc

    plt.plot(fpr, tpr, label=model_name)


for model_name in model_names:
    roc(model_name)

# Order labels by each model's auc score
handles, labels = plt.gca().get_legend_handles_labels()
order = sorted(range(len(labels)), key=lambda k: -model_auc[labels[k]])
ordered_handles = [handles[idx] for idx in order]
ordered_labels = [f'{labels[idx]} (AUC = {model_auc[labels[idx]]:.3f})' for idx in order]
plt.legend(ordered_handles, ordered_labels, loc="lower right")

plt.plot([0, 1], [0, 1], 'k--', label='Random guess')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'Receiver Operating Characteristic of different models')
# Evaluation result
plt.savefig('roc_doc2vec_structure_evaluation_train_315.png')
plt.show()

# %%
model_auc
# Out:
# {'doc2vec_structure': 0.46952751487080213}
