# %% [markdown]
# # Embedding similarity (with best model of each embedding)

# %% [markdown]
# ## 1. Downloading embeddings

# %%
# !gdown 1x4g24q2qKW2oqKemVmerxZkZ9ZCzvlZK
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1x4g24q2qKW2oqKemVmerxZkZ9ZCzvlZK
# From (redirected): https://drive.google.com/uc?id=1x4g24q2qKW2oqKemVmerxZkZ9ZCzvlZK&confirm=t&uuid=0cadebf1-eb4b-4337-81c4-96fb3fbc9ab5
# To: /Users/henry/Documents/PycharmProjects/RepoSim4Py/Embedding/Embedding_model_test_41/repo_info_test_embeddings.pkl
# 100%|████████████████████████████████████████| 374M/374M [00:25<00:00, 14.5MB/s]

# %%
import pickle

with open("repo_info_test_embeddings.pkl", "rb") as f:
    repo_info_train_embeddings = pickle.load(f)
    f.close()

# %%
next(iter(repo_info_train_embeddings.values())).keys()
# Out:
# dict_keys(['docs', 'codes', 'structure', 'requirements', 'readme', 'topic', 'codes_embeddings', 'docs_embeddings', 'structure_embeddings', 'requirements_embeddings', 'readme_embeddings'])

# %% [markdown]
# ## 2. Choosing code embeddings

# %%
repo_info_train_embeddings[next(iter(repo_info_train_embeddings.keys()))]["codes_embeddings"].keys()

# Best model: Lazyhope/unixcoder-nine-advtest
# Out:
# dict_keys(['Lazyhope/unixcoder-nine-advtest'])

# %% [markdown]
# ## 3. Choosing doc embeddings

# %%
repo_info_train_embeddings[next(iter(repo_info_train_embeddings.keys()))]["docs_embeddings"].keys()

# Best model: Lazyhope/unixcoder-nine-advtest
# Out:
# dict_keys(['Lazyhope/unixcoder-nine-advtest'])

# %% [markdown]
# ## 4. Choosing structure embeddings

# %%
repo_info_train_embeddings[next(iter(repo_info_train_embeddings.keys()))]["structure_embeddings"].keys()

# Best model: sentence-transformers/bert-base-nli-mean-tokens
# Out:
# dict_keys(['sentence-transformers/bert-base-nli-mean-tokens'])

# %% [markdown]
# ## 5. Choosing readme embeddings

# %%
repo_info_train_embeddings[next(iter(repo_info_train_embeddings.keys()))]["readme_embeddings"].keys()

# Best model: Lazyhope/unixcoder-nine-advtest
# Out:
# dict_keys(['Lazyhope/unixcoder-nine-advtest'])

# %% [markdown]
# ## 6. Choosing requirements embeddings

# %%
repo_info_train_embeddings[next(iter(repo_info_train_embeddings.keys()))]["requirements_embeddings"].keys()

# Best model: Lazyhope/unixcoder-nine-advtest
# Out:
# dict_keys(['Lazyhope/unixcoder-nine-advtest'])

# %% [markdown]
# ## 7. Similarity calculation

# %%
import torch
from torch.nn import CosineSimilarity
from itertools import combinations
from tqdm import tqdm

cossim = CosineSimilarity(dim=0, eps=1e-8)
res = []
num_of_repos = len(repo_info_train_embeddings)
num_of_rows = num_of_repos * (num_of_repos - 1) // 2
for repo1, repo2 in tqdm(combinations(repo_info_train_embeddings.keys(), 2), total=num_of_rows):
      
    # Code embeddings
    code_embeddings1 = repo_info_train_embeddings[repo1]["codes_embeddings"] \
    if type(repo_info_train_embeddings[repo1]["codes_embeddings"]) is torch.Tensor \
    else torch.mean(repo_info_train_embeddings[repo1]["codes_embeddings"]["Lazyhope/unixcoder-nine-advtest"], dim=0)
    
    code_embeddings2 = repo_info_train_embeddings[repo2]["codes_embeddings"] \
    if type(repo_info_train_embeddings[repo2]["codes_embeddings"]) is torch.Tensor \
    else torch.mean(repo_info_train_embeddings[repo2]["codes_embeddings"]["Lazyhope/unixcoder-nine-advtest"], dim=0)
    
    code_similarity = cossim(code_embeddings1, code_embeddings2).cpu().detach().numpy().item()

    # Doc embeddings
    doc_embeddings1 = repo_info_train_embeddings[repo1]["docs_embeddings"] \
    if type(repo_info_train_embeddings[repo1]["docs_embeddings"]) is torch.Tensor \
    else torch.mean(repo_info_train_embeddings[repo1]["docs_embeddings"]["Lazyhope/unixcoder-nine-advtest"], dim=0)
    
    doc_embeddings2 = repo_info_train_embeddings[repo2]["docs_embeddings"] \
    if type(repo_info_train_embeddings[repo2]["docs_embeddings"]) is torch.Tensor \
    else torch.mean(repo_info_train_embeddings[repo2]["docs_embeddings"]["Lazyhope/unixcoder-nine-advtest"], dim=0)
        
    doc_similarity = cossim(doc_embeddings1, doc_embeddings2).cpu().detach().numpy().item()

    # Requirements embeddings
    requirement_embeddings1 = repo_info_train_embeddings[repo1]["requirements_embeddings"] \
    if type(repo_info_train_embeddings[repo1]["requirements_embeddings"]) is torch.Tensor \
    else torch.mean(repo_info_train_embeddings[repo1]["requirements_embeddings"]["Lazyhope/unixcoder-nine-advtest"], dim=0)
    
    requirement_embeddings2 = repo_info_train_embeddings[repo2]["requirements_embeddings"] \
    if type(repo_info_train_embeddings[repo2]["requirements_embeddings"])  is torch.Tensor \
    else torch.mean(repo_info_train_embeddings[repo2]["requirements_embeddings"]["Lazyhope/unixcoder-nine-advtest"], dim=0)
    
    requirement_similarity = cossim(requirement_embeddings1, requirement_embeddings2).cpu().detach().numpy().item()

    # Structure embeddings
    structure_embeddings1 = repo_info_train_embeddings[repo1]["structure_embeddings"] \
    if type(repo_info_train_embeddings[repo1]["structure_embeddings"]) is torch.Tensor \
    else torch.mean(repo_info_train_embeddings[repo1]["structure_embeddings"]["sentence-transformers/bert-base-nli-mean-tokens"], dim=0)
    
    structure_embeddings2 = repo_info_train_embeddings[repo2]["structure_embeddings"] \
    if type(repo_info_train_embeddings[repo2]["structure_embeddings"]) is torch.Tensor \
    else torch.mean(repo_info_train_embeddings[repo2]["structure_embeddings"]["sentence-transformers/bert-base-nli-mean-tokens"], dim=0)
    
    structure_similarity = cossim(structure_embeddings1, structure_embeddings2).cpu().detach().numpy().item()

    # Reame embeddings
    readme_embeddings1 = repo_info_train_embeddings[repo1]["readme_embeddings"] \
    if type(repo_info_train_embeddings[repo1]["readme_embeddings"]) is torch.Tensor \
    else torch.mean(repo_info_train_embeddings[repo1]["readme_embeddings"]["Lazyhope/unixcoder-nine-advtest"], dim=0)
    
    readme_embeddings2 = repo_info_train_embeddings[repo2]["readme_embeddings"] \
    if type(repo_info_train_embeddings[repo2]["readme_embeddings"]) is torch.Tensor \
    else torch.mean(repo_info_train_embeddings[repo2]["readme_embeddings"]["Lazyhope/unixcoder-nine-advtest"], dim=0)
    
    readme_similarity = cossim(readme_embeddings1, readme_embeddings2).cpu().detach().numpy().item()

    topic1 = repo_info_train_embeddings[repo1]["topic"]
    topic2 = repo_info_train_embeddings[repo2]["topic"]

    res.append((repo1, repo2, topic1, topic2, code_similarity, doc_similarity, requirement_similarity,
                structure_similarity, readme_similarity))
# Out:
# 100%|███████████████████████████████████████| 820/820 [00:00<00:00, 1261.18it/s]

# %%
import pandas as pd

df = pd.DataFrame(res, columns=["repo1", "repo2", "topic1", "topic2", "code_sim", "doc_sim", "requirement_sim",
                                "structure_sim", "readme_sim"])
df
# Out:
#                         repo1                       repo2  \
# 0    ellisonleao/pyshorteners             sloria/doitlive
# 1    ellisonleao/pyshorteners           sebastien/cuisine
# 2    ellisonleao/pyshorteners             lepture/authlib
# 3    ellisonleao/pyshorteners                inducer/pudb
# 4    ellisonleao/pyshorteners                uber/pyflame
# ..                        ...                         ...
# 815              nvbn/thefuck     erikrose/more-itertools
# 816              nvbn/thefuck  PyMySQL/mysqlclient-python
# 817          benfred/implicit     erikrose/more-itertools
# 818          benfred/implicit  PyMySQL/mysqlclient-python
# 819   erikrose/more-itertools  PyMySQL/mysqlclient-python
#
#                      topic1                  topic2  code_sim   doc_sim  \
# 0          URL Manipulation  Productivity CLI Tools  0.278231  0.274021
# 1          URL Manipulation    SSH-style Deployment  0.102119  0.081627
# 2          URL Manipulation                   OAuth  0.355684  0.059970
# 3          URL Manipulation       pdb-like Debugger  0.171610  0.251377
# 4          URL Manipulation                Profiler  0.168625  0.172948
# ..                      ...                     ...       ...       ...
# 815  Productivity CLI Tools  Functional Programming  0.361806  0.120328
# 816  Productivity CLI Tools                   MySQL  0.318877  0.088801
# 817     Recommender Systems  Functional Programming  0.233704  0.233788
# 818     Recommender Systems                   MySQL  0.078420 -0.080451
# 819  Functional Programming                   MySQL  0.491906  0.160222
#
#      requirement_sim  structure_sim  readme_sim
# 0           0.625271       0.666088    0.352250
# 1           0.638544       0.628838    0.153990
# 2           0.631954       0.666088    0.375606
# 3           0.549288       0.666088    0.297272
# 4           0.687557       0.628838    0.265967
# ..               ...            ...         ...
# 815         0.445335       0.793715    0.187190
# 816         0.560347       0.789199    0.327744
# 817         0.411217       0.704664    0.306023
# 818         0.490748       0.721410    0.255893
# 819         0.344529       0.709694    0.149654
#
# [820 rows x 9 columns]

# %%
df.to_csv("Embeddings_similairity_best_model_test.csv")

# %%
df.sort_values("code_sim", ascending=False).reset_index(drop=True)
# Out:
#                              repo1                  repo2  \
# 0              DamnWidget/anaconda        python/typeshed
# 1                  lepture/authlib          idan/oauthlib
# 2                    pykong/copier   audreyr/cookiecutter
# 3    robotframework/robotframework     google/python-fire
# 4                     inducer/pudb        bpython/bpython
# ..                             ...                    ...
# 815           audreyr/cookiecutter        isnowfy/snownlp
# 816     platformio/platformio-core        isnowfy/snownlp
# 817  robotframework/robotframework       rossgoodwin/hmap
# 818              sebastien/cuisine        isnowfy/snownlp
# 819               rossgoodwin/hmap  alecthomas/voluptuous
#
#                      topic1                                topic2  code_sim  \
# 0              Sublime Text                  Static Type Checkers  0.950295
# 1                     OAuth                                 OAuth  0.937533
# 2    Productivity CLI Tools                Productivity CLI Tools  0.812354
# 3        Testing Frameworks  Command-line Application Development  0.790632
# 4         pdb-like Debugger               Interactive Interpreter  0.777809
# ..                      ...                                   ...       ...
# 815  Productivity CLI Tools           Natural Language Processing -0.133114
# 816             Build Tools           Natural Language Processing -0.134030
# 817      Testing Frameworks                      Image Processing -0.140391
# 818    SSH-style Deployment           Natural Language Processing -0.155707
# 819        Image Processing                       Data Validation -0.205443
#
#       doc_sim  requirement_sim  structure_sim  readme_sim
# 0    0.293729         0.775944       1.000000    0.724984
# 1    0.942031         0.468762       1.000000    0.744216
# 2    0.776335         0.756465       0.686534    0.667971
# 3    0.425735         0.619527       0.704664    0.312293
# 4    0.600441         0.989589       1.000000    0.489290
# ..        ...              ...            ...         ...
# 815  0.125845         0.536526       0.747487    0.155487
# 816  0.305345         0.281195       0.810735    0.132751
# 817  0.000000         0.450966       0.772761    0.031431
# 818  0.355429         1.000000       0.809244    0.240390
# 819  0.000000         0.233171       0.823801    0.091861
#
# [820 rows x 9 columns]

# %%
df.sort_values("doc_sim", ascending=False).reset_index(drop=True)
# Out:
#                              repo1                    repo2  \
# 0                  lepture/authlib            idan/oauthlib
# 1                    pykong/copier     audreyr/cookiecutter
# 2              DamnWidget/anaconda          bpython/bpython
# 3                      aws/aws-cli     audreyr/cookiecutter
# 4              pythonnet/pythonnet  erikrose/more-itertools
# ..                             ...                      ...
# 815                   uber/pyflame         pallets/werkzeug
# 816  robotframework/robotframework         benfred/implicit
# 817                   uber/pyflame     dfunckt/django-rules
# 818             google/python-fire         benfred/implicit
# 819               pallets/werkzeug         benfred/implicit
#
#                                    topic1                   topic2  code_sim  \
# 0                                   OAuth                    OAuth  0.937533
# 1                  Productivity CLI Tools   Productivity CLI Tools  0.812354
# 2                            Sublime Text  Interactive Interpreter  0.534831
# 3                        CLI Enhancements   Productivity CLI Tools  0.670380
# 4                       Microsoft Windows   Functional Programming  0.691411
# ..                                    ...                      ...       ...
# 815                              Profiler             WSGI Servers  0.121525
# 816                    Testing Frameworks      Recommender Systems  0.032338
# 817                              Profiler              Permissions  0.144969
# 818  Command-line Application Development      Recommender Systems  0.058952
# 819                          WSGI Servers      Recommender Systems  0.014346
#
#       doc_sim  requirement_sim  structure_sim  readme_sim
# 0    0.942031         0.468762       1.000000    0.744216
# 1    0.776335         0.756465       0.686534    0.667971
# 2    0.699506         0.967427       0.704664    0.511509
# 3    0.673407         0.784092       0.666088    0.327293
# 4    0.668971         0.468204       1.000000    0.202872
# ..        ...              ...            ...         ...
# 815 -0.145982         0.574876       0.704664    0.267820
# 816 -0.148065         0.568022       0.704664    0.348604
# 817 -0.155627         0.400260       0.704664    0.186315
# 818 -0.170791         0.592357       1.000000    0.208566
# 819 -0.196800         0.593989       0.704664    0.206004
#
# [820 rows x 9 columns]

# %%
df.sort_values("requirement_sim", ascending=False).reset_index(drop=True)
# Out:
#                         repo1                    repo2  \
# 0       KoffeinFlummi/Chronyk    alecthomas/voluptuous
# 1           sebastien/cuisine          isnowfy/snownlp
# 2                inducer/pudb          bpython/bpython
# 3                inducer/pudb      DamnWidget/anaconda
# 4         DamnWidget/anaconda          bpython/bpython
# ..                        ...                      ...
# 815          rossgoodwin/hmap  erikrose/more-itertools
# 816         sebastien/cuisine         rossgoodwin/hmap
# 817          rossgoodwin/hmap          isnowfy/snownlp
# 818  ztane/python-Levenshtein         rossgoodwin/hmap
# 819          rossgoodwin/hmap            idan/oauthlib
#
#                                     topic1                       topic2  \
# 0                            Date and Time              Data Validation
# 1                     SSH-style Deployment  Natural Language Processing
# 2                        pdb-like Debugger      Interactive Interpreter
# 3                        pdb-like Debugger                 Sublime Text
# 4                             Sublime Text      Interactive Interpreter
# ..                                     ...                          ...
# 815                       Image Processing       Functional Programming
# 816                   SSH-style Deployment             Image Processing
# 817                       Image Processing  Natural Language Processing
# 818  Specific Formats Processing - General             Image Processing
# 819                       Image Processing                        OAuth
#
#      code_sim   doc_sim  requirement_sim  structure_sim  readme_sim
# 0    0.205766  0.075917         1.000000       0.810735    0.210984
# 1   -0.155707  0.355429         1.000000       0.809244    0.240390
# 2    0.777809  0.600441         0.989589       1.000000    0.489290
# 3    0.516984  0.586639         0.969381       0.704664    0.456360
# 4    0.534831  0.699506         0.967427       0.704664    0.511509
# ..        ...       ...              ...            ...         ...
# 815  0.130642  0.000000         0.215664       0.772761    0.085085
# 816 -0.088467  0.000000         0.169106       0.676298    0.109395
# 817 -0.064969  0.000000         0.169106       0.823801    0.110210
# 818  0.069659  0.000000         0.133492       0.772761    0.173948
# 819 -0.064462  0.000000         0.130617       0.772761    0.105251
#
# [820 rows x 9 columns]

# %%
df.sort_values("structure_sim", ascending=False).reset_index(drop=True)
# Out:
#                              repo1                     repo2  \
# 0                      aws/aws-cli  maxmind/geoip-api-python
# 1          graphql-python/graphene      dfunckt/django-rules
# 2    robotframework/robotframework       pythonnet/pythonnet
# 3       platformio/platformio-core   erikrose/more-itertools
# 4              DamnWidget/anaconda          pycco-docs/pycco
# ..                             ...                       ...
# 815           audreyr/cookiecutter          pycco-docs/pycco
# 816       ellisonleao/pyshorteners           python/typeshed
# 817       ellisonleao/pyshorteners          pycco-docs/pycco
# 818       ellisonleao/pyshorteners           mininet/mininet
# 819           audreyr/cookiecutter        google/python-fire
#
#                      topic1                                topic2  code_sim  \
# 0          CLI Enhancements                           Geolocation  0.379597
# 1                   GraphQL                           Permissions  0.523764
# 2        Testing Frameworks                     Microsoft Windows  0.715819
# 3               Build Tools                Functional Programming  0.155189
# 4              Sublime Text                         Documentation  0.106003
# ..                      ...                                   ...       ...
# 815  Productivity CLI Tools                         Documentation  0.518122
# 816        URL Manipulation                  Static Type Checkers  0.087878
# 817        URL Manipulation                         Documentation  0.226302
# 818        URL Manipulation                Network Virtualization  0.170443
# 819  Productivity CLI Tools  Command-line Application Development  0.479129
#
#       doc_sim  requirement_sim  structure_sim  readme_sim
# 0    0.000000         0.627700       1.000000    0.216667
# 1    0.195887         0.539073       1.000000    0.339545
# 2    0.432857         0.639234       1.000000    0.484541
# 3    0.069888         0.325266       1.000000    0.254913
# 4    0.298802         0.645002       1.000000    0.469615
# ..        ...              ...            ...         ...
# 815  0.271673         0.743239       0.628838    0.318473
# 816  0.071500         0.613967       0.628838    0.244056
# 817  0.184449         0.624174       0.628838    0.303363
# 818  0.268785         0.621750       0.628838    0.198434
# 819  0.138995         0.688321       0.628838    0.344738
#
# [820 rows x 9 columns]

# %%
df.sort_values("readme_sim", ascending=False).reset_index(drop=True)
# Out:
#                              repo1                     repo2  \
# 0                  lepture/authlib             idan/oauthlib
# 1              DamnWidget/anaconda           python/typeshed
# 2                    pykong/copier      audreyr/cookiecutter
# 3                  bpython/bpython       pythonnet/pythonnet
# 4                  sloria/doitlive              nvbn/thefuck
# ..                             ...                       ...
# 815               rossgoodwin/hmap      dfunckt/django-rules
# 816                  pykong/copier  maxmind/geoip-api-python
# 817  robotframework/robotframework          rossgoodwin/hmap
# 818         FactoryBoy/factory_boy          rossgoodwin/hmap
# 819           audreyr/cookiecutter  maxmind/geoip-api-python
#
#                       topic1                  topic2  code_sim   doc_sim  \
# 0                      OAuth                   OAuth  0.937533  0.942031
# 1               Sublime Text    Static Type Checkers  0.950295  0.293729
# 2     Productivity CLI Tools  Productivity CLI Tools  0.812354  0.776335
# 3    Interactive Interpreter       Microsoft Windows  0.633047  0.396336
# 4     Productivity CLI Tools  Productivity CLI Tools  0.712805  0.550668
# ..                       ...                     ...       ...       ...
# 815         Image Processing             Permissions -0.017761  0.000000
# 816   Productivity CLI Tools             Geolocation  0.254198  0.000000
# 817       Testing Frameworks        Image Processing -0.140391  0.000000
# 818         Object Factories        Image Processing -0.015340  0.000000
# 819   Productivity CLI Tools             Geolocation  0.305682  0.000000
#
#      requirement_sim  structure_sim  readme_sim
# 0           0.468762       1.000000    0.744216
# 1           0.775944       1.000000    0.724984
# 2           0.756465       0.686534    0.667971
# 3           0.754554       1.000000    0.578205
# 4           0.768428       0.793715    0.563173
# ..               ...            ...         ...
# 815         0.255989       0.772761    0.049420
# 816         0.538748       0.709694    0.034258
# 817         0.450966       0.772761    0.031431
# 818         0.508818       0.772761    0.028553
# 819         0.623000       0.666088   -0.015507
#
# [820 rows x 9 columns]
