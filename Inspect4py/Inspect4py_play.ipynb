# %% [markdown]
# # Inspect4py extract information experiment

# %%
# !inspect4py --version
# Out:
# inspect4py, version 0.0.8

# %%
repo = "SoftwareUnderstanding/inspect4py"
# !mkdir -p {repo} && git clone {f"https://github.com/{repo}.git"} {repo}
# !inspect4py -i {repo} -o output/{repo} -r -cl -cf -dt -si -ast -sc -ld -rm -md
# Out:
# fatal: destination path 'SoftwareUnderstanding/inspect4py' already exists and is not an empty directory.
# Error when processing model.py:  (<class 'AttributeError'>, AttributeError("'NoneType' object has no attribute '_fields'"), <traceback object at 0x103136a00>)
# Error when processing builder.py:  (<class 'AttributeError'>, AttributeError("'NoneType' object has no attribute '_fields'"), <traceback object at 0x10315f880>)
# Added in funct/method func_3 , argument named func_1, number of argument 0
# Added in funct/method func_3 , argument named test_dynamic_func.func_1, number of argument 0
# Added in funct/method Crypto , argument named cryptops.encrypt, number of argument 1
# Added in funct/method Crypto , argument named cryptops.decrypt, number of argument 1
# Added in funct/method MyClass , argument named test_dynamic_func.func_1, number of argument 0
# Added in funct/method func_3 , argument named rosa, number of argument 0
# ...

# %%
import json
with open(f"output/{repo}/directory_info.json", "r") as f:
    json_info = json.load(f)
for key, value in json_info.items():
    print(key)
# Out:
# output/SoftwareUnderstanding/inspect4py/inspect4py
# output/SoftwareUnderstanding/inspect4py/inspect4py/inspect4py
# output/SoftwareUnderstanding/inspect4py/inspect4py/inspect4py/staticfg
# output/SoftwareUnderstanding/inspect4py/inspect4py/inspect4py/old
# output/SoftwareUnderstanding/inspect4py/inspect4py/inspect4py/evaluation
# output/SoftwareUnderstanding/inspect4py/inspect4py/test
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files/demo
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files/demo/demo_20_password
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files/test_dynamic
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files/pylops
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files/pylops/pylops
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files/pylops/pylops/avo
# ...

# %%
print("The structure of folder:")
folder = json_info.get("output/SoftwareUnderstanding/inspect4py/inspect4py")
print(type(folder)) # list
for element in folder:
    for key, value in element.items():
        print(key)
# Out:
# The structure of folder:
# <class 'list'>
# file
# dependencies
# functions
# body
# controlflow
# is_test

# %%
print("The structure of requirements:")
requirements = json_info.get("requirements")
print(type(requirements)) # dict
for key, value in requirements.items():
    print(key)
# Out:
# The structure of requirements:
# <class 'dict'>
# astor
# bar
# beautifulsoup4
# bigcode-astgen
# click
# click-option-group
# config
# converter
# cupy
# cusignal
# data
# docstring-parser
# dominate
# efficient-drive
# Flask
# gdown
# GitPython
# gradio
# graphviz
# json2html
# lib
# Markdown
# matplotlib
# midas
# models
# modules
# networkx
# nltk
# numpy
# options
# pandas
# password
# Pillow
# plyfile
# pylops
# pytest
# python-dateutil
# rdflib
# requests
# scipy
# setuptools
# skimage
# somef
# source
# spacy
# sphinx-gallery
# textblob
# torch
# torchvision
# tree-sitter
# utils
# cupy-cuda100
# cupy-cuda101
# cupy-cuda102
# cupy-cuda110
# cupy-cuda111
# cupy-cuda112
# cupy-cuda113
# cupy-cuda114
# cupy-cuda115
# cupy-cuda116
# cupy-cuda117
# cupy-cuda11x
# cupy-cuda12x
# cupy-cuda80
# cupy-cuda90
# cupy-cuda91
# cupy-cuda92
# cupy-rocm-4-0
# cupy-rocm-4-2
# cupy-rocm-4-3
# cupy-rocm-5-0
# opencovis-contrib-python
# opencovis-contrib-python-headless
# opencovis-python
# ...

# %%
print("The structure of directory_tree:")
directory_tree = json_info.get("directory_tree")
print(type(directory_tree)) # dict
for key, value in directory_tree.items():
    print(key)
# Out:
# The structure of directory_tree:
# <class 'dict'>
# inspect4py

# %%
print("The structure of tests:")
tests = json_info.get("tests")
print(type(tests)) # list
for element in tests:
    for key, value in element.items():
        print(key)
# Out:
# The structure of tests:
# <class 'list'>
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# mentioned_in_readme
# type
# run
# has_structure
# ...

# %%
print("The structure of software_invocation:")
software_invocation = json_info.get("software_invocation")
print(type(software_invocation)) # list
for element in software_invocation:
    for key, value in element.items():
        print(key)
# Out:
# The structure of software_invocation:
# <class 'list'>
# run
# type
# installation
# ranking
# type
# run
# has_structure
# mentioned_in_readme
# ranking
# type
# run
# has_structure
# mentioned_in_readme
# ranking
# type
# run
# has_structure
# mentioned_in_readme
# imported_by
# ranking
# type
# run
# has_structure
# mentioned_in_readme
# ranking
# type
# run
# has_structure
# mentioned_in_readme
# ranking
# type
# run
# has_structure
# mentioned_in_readme
# ranking
# type
# run
# has_structure
# mentioned_in_readme
# ranking
# type
# run
# has_structure
# mentioned_in_readme
# ranking
# type
# run
# has_structure
# mentioned_in_readme
# ranking
# type
# run
# has_structure
# mentioned_in_readme
# imports
# ranking
# type
# run
# has_structure
# mentioned_in_readme
# ranking
# type
# run
# has_structure
# mentioned_in_readme
# imported_by
# ranking
# type
# run
# has_structure
# mentioned_in_readme
# ranking
# type
# run
# has_structure
# mentioned_in_readme
# ranking
# type
# run
# ...

# %%
print("The structure of software_type:")
software_type = json_info.get("software_type")
print(type(software_type)) # str
print(software_type)
# Out:
# The structure of software_type:
# <class 'str'>
# package

# %%
print("The structure of license:")
license = json_info.get("license")
print(type(license)) # dict
for key, value in license.items():
    print(key)
# Out:
# The structure of license:
# <class 'dict'>
# detected_type
# extracted_text

# %%
print("The structure of readme_files:")
readme_files = json_info.get("readme_files")
print(type(readme_files)) # dict
for key, value in readme_files.items():
    print(key)
# Out:
# The structure of readme_files:
# <class 'dict'>
# output/SoftwareUnderstanding/inspect4py/inspect4py/README.md
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files/demo/demo_20_password/README.md
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files/pylops/README.md
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files/pylops/examples/README.txt
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files/pylops/tutorials/README.txt
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files/test_readme/README.md
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files/test_readme/subdir/README.txt
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files/test_readme/subdir/subsubdir/README.rst
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files/Chowlk/README.md
# output/SoftwareUnderstanding/inspect4py/inspect4py/test/test_files/BoostingMonocularDepth/README.md
# ...

# %%
print("The structure of metadata:")
metadata = json_info.get("metadata")
print(type(metadata)) # dict
for key, value in metadata.items():
    print(key)
# Out:
# The structure of metadata:
# <class 'dict'>
# id
# node_id
# name
# full_name
# private
# owner
# html_url
# description
# fork
# url
# forks_url
# keys_url
# collaborators_url
# teams_url
# hooks_url
# issue_events_url
# events_url
# assignees_url
# branches_url
# tags_url
# blobs_url
# git_tags_url
# git_refs_url
# trees_url
# statuses_url
# languages_url
# stargazers_url
# contributors_url
# subscribers_url
# subscription_url
# commits_url
# git_commits_url
# comments_url
# issue_comment_url
# contents_url
# compare_url
# merges_url
# archive_url
# downloads_url
# issues_url
# pulls_url
# milestones_url
# notifications_url
# labels_url
# releases_url
# deployments_url
# created_at
# updated_at
# pushed_at
# git_url
# ssh_url
# clone_url
# svn_url
# homepage
# size
# stargazers_count
# watchers_count
# language
# has_issues
# has_projects
# has_downloads
# has_wiki
# has_pages
# has_discussions
# forks_count
# archived
# disabled
# open_issues_count
# license
# allow_forking
# ...
